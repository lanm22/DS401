# %% [markdown]
# # Boxplot split axis & Tukey test: Merrina

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(font='Helvetica')
sns.set_style('dark')
sns.set_palette('colorblind')
sns.set_style("ticks", {"xtick.major.size": 8, "ytick.major.size": 8})
from math import e

# %% [markdown]
# # Major ampullate plots

# %%
all_genes=pd.read_excel('All genes_corrected _new_actin.xlsx')

# %%
# boxplot without split axis
a = sns.boxplot(x='Diet',y='MaSp1:MaSp2',data=all_genes,palette='Paired')
sns.despine()
a.set_xlabel('MaSp1:MaSp2', fontsize=15)
a.set_ylabel('Diet', fontsize=15)
a.tick_params(labelsize=15)
a.axes.set_title('MaSp1 to MaSp2 ratio in different diets for major ampullate', fontsize=18)
#plt.title('MaSp1 to MaSp2 ratio in different diets for major ampullate')
# Out:
# Text(0.5,1,'MaSp1 to MaSp2 ratio in different diets for major ampullate')

# %% [markdown]
# Problems:
#
# 1. I don't know how to remove the x axis labels (baseline, criket, fly-fed) for the top subplot
# 2. when I remove the x axis line, the one on the bottom is gone too
# 3. I have no idea why the y axis for the top subplot has decimal points
#
# Update: problems solved on 7/22/2019

# %%
from PIL import Image
import io

f, axes = plt.subplots(nrows=2, ncols=1, sharex=True, sharey=False,
                       gridspec_kw={'height_ratios':[1,2]}) 

# use this to squeeze the 2 subplots super close to cover the category labels
plt.subplots_adjust(hspace=0.01) 
plt.title('MaSp1:MaSp2 in Major',y=1.55)
#sns.despine(bottom=True)
sns.boxplot(x='Diet',y='MaSp1:MaSp2',data=all_genes,ax=axes[0], palette='Paired')

axes[0].set_ylim(6,7.1)
axes[0].set_ylabel('')
axes[0].tick_params(labelsize=15)

#sns.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)

a=sns.boxplot(x='Diet',y='MaSp1:MaSp2',data=all_genes,ax=axes[1])
axes[1].set_ylim(0,2.4)
axes[1].set_ylabel('')
axes[1].set_xlabel('')
t= axes[1].text(-0.07,0.95,'==',size=14,ha='left',transform=axes[1].transAxes)
t.set_bbox(dict(facecolor='white',edgecolor='white'))
#plt.savefig('SA_MaSp1 to MaSp2 in Major.png') # SA for split axis

a.tick_params(labelsize=15)
a.axes.set_title('MaSp1 to MaSp2 in major', fontsize=18)

# Save the image in memory in PNG format
png1 = io.BytesIO()
plt.savefig(png1, format="png")

# Load this image into PIL
png2 = Image.open(png1)

# Save as TIFF
png2.save("SA_MaSp1 to MaSp2 in Major.tiff")
png1.close()

# %%
f, axes = plt.subplots(nrows=2, ncols=1, sharex=True, sharey=False,
                       gridspec_kw={'height_ratios':[1,2]}) 

# use this to squeeze the 2 subplots super close to cover the category labels
plt.subplots_adjust(hspace=0.01) 
plt.title('MaSp1:MaSp2 in Major',y=1.55)
#sns.despine(bottom=True)
sns.boxplot(x='Diet',y='MaSp1:MaSp2',data=all_genes,ax=axes[0], palette='Paired')

axes[0].set_ylim(6,7.1)
axes[0].set_ylabel('')
axes[0].tick_params(labelsize=15)

#sns.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)

a=sns.boxplot(x='Diet',y='MaSp1:MaSp2',data=all_genes,ax=axes[1])
axes[1].set_ylim(0,2.4)
axes[1].set_ylabel('')
axes[1].set_xlabel('')
t= axes[1].text(-0.07,0.95,'==',size=14,ha='left',transform=axes[1].transAxes)
t.set_bbox(dict(facecolor='white',edgecolor='white'))
#plt.savefig('SA_MaSp1 to MaSp2 in Major.png') # SA for split axis

a.tick_params(labelsize=15)
a.axes.set_title('MaSp1 to MaSp2 in major', fontsize=18)

plt.savefig("SA_MaSp1 to MaSp2 in Major.pdf")

# %%
f, axes = plt.subplots(nrows=2, ncols=1, sharex=True, sharey=False,
                       gridspec_kw={'height_ratios':[1,2]}) 

# use this to squeeze the 2 subplots super close to cover the category labels
plt.subplots_adjust(hspace=0.01) 
plt.title('MaSp1:Actin in Major',y=1.55)
#sns.despine(bottom=True)
sns.boxplot(x='Diet',y='MaSp1:actin',data=all_genes,ax=axes[0], palette='Paired')

axes[0].set_ylim(1*1e7,1.5*1e7)
axes[0].set_ylabel('')
axes[0].tick_params(labelsize=15)
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))

#sns.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)

a=sns.boxplot(x='Diet',y='MaSp1:actin',data=all_genes,ax=axes[1])
axes[1].set_ylim(0, 2.5*1e6)
axes[1].set_ylabel('')
axes[1].set_xlabel('')
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
t= axes[1].text(-0.12,0.95,'===',size=14,ha='left',transform=axes[1].transAxes)
t.set_bbox(dict(facecolor='white',edgecolor='white'))
#plt.savefig('SA_MaSp1 to MaSp2 in Major.png') # SA for split axis

a.tick_params(labelsize=15)
a.axes.set_title('MaSp1:Actin in major', fontsize=18)

plt.savefig("SA_MaSp1 to Actin in Major.pdf")

# %%
a = sns.boxplot(x='Diet',y='MaSp1:actin',data=all_genes,palette='colorblind')
a.set_xlabel('MaSp1:Actin', fontsize=15)
a.set_ylabel('Diet', fontsize=15)
a.tick_params(labelsize=15)
a.set_ylabel('')
a.set_xlabel('')
a.axes.set_title('MaSp1 to Actin in Major', fontsize=18)
plt.savefig("SA_MaSp1 to Actin in Major.pdf")

# %%
f, axes = plt.subplots(nrows=2, ncols=1, sharex=True, sharey=False,
                       gridspec_kw={'height_ratios':[1,2]}) 

# use this to squeeze the 2 subplots super close to cover the category labels
plt.subplots_adjust(hspace=0.01) 
plt.title('MaSp1:MaSp2 in Major',y=1.55, fontsize=18)

sns.boxplot(x='Diet',y='MaSp1:MaSp2',data=all_genes,ax=axes[0])

axes[0].set_ylim(6,7.1)
axes[0].set_ylabel('')
axes[0].tick_params(labelsize=15)

#sns.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)

a=sns.boxplot(x='Diet',y='MaSp1:MaSp2',data=all_genes,ax=axes[1])
axes[1].set_ylim(0,2.5)
axes[1].set_ylabel('')
axes[1].set_xlabel('')
a.tick_params(labelsize=15)
t= axes[1].text(-0.09,0.95,'===',size=14,ha='left',transform=axes[1].transAxes)
t.set_bbox(dict(facecolor='white',edgecolor='white'))
plt.savefig('SA_MaSp1 to MaSp2 in Major.pdf') # SA for split axis

# %%
from PIL import Image
import io

f, axes = plt.subplots(nrows=2, ncols=1, sharex=True, sharey=False,
                       gridspec_kw={'height_ratios':[1,2]}) 
#plt.ticklabel_format(useOffset=False)

#axes[0].yaxis.get_offset_text().set_visible(False)
# use this to squeeze the 2 subplots super close to cover the category labels
plt.subplots_adjust(hspace=0.01) 
#plt.title('MaSp1 to Actin in Major',y=1.55)

plt.ticklabel_format(style='plain',axis='y')
#sns.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)
#plt.ticklabel_format(style='sci',axis='y',scilimits=(0,11))
sns.boxplot(x='Diet',y='MaSp1:actin',data=all_genes,ax=axes[1])
axes[1].set_ylim(0,20000000)
axes[1].set_ylabel('')
axes[1].set_xlabel('')

#sns.despine(bottom=True)
a=sns.boxplot(x='Diet',y='MaSp1:actin',data=all_genes,ax=axes[0])

plt.ticklabel_format(style='plain',axis='y')

axes[0].set_ylim(75000000,90000000)
axes[0].set_ylabel('')

t= axes[1].text(-0.8,0.95,'======',size=14,ha='left',transform=axes[1].transAxes)
t.set_bbox(dict(facecolor='white',edgecolor='white'))

a.tick_params(labelsize=15)
a.axes.set_title('MaSp1 to Actin in major', fontsize=18)

plt.savefig("SA_MaSp1 to Actin in Major.pdf")
#plt.savefig("SA_MaSp1 to Actin in Major.pdf")
#png1 = io.BytesIO()
#plt.savefig(png1, format="png")

# Load this image into PIL
#png2 = Image.open(png1)

# Save as TIFF
#png2.save("SA_MaSp1 to Actin in Major.tiff")
#png1.close()
#plt.savefig('SA_MaSp1 to Actin in Major.png') # SA for split axis

# %%
#from PIL import Image
#import io

f, axes = plt.subplots(nrows=2, ncols=1, sharex=True, sharey=False,
                       gridspec_kw={'height_ratios':[1,2]}) 
#plt.ticklabel_format(style='plain',axis='y')
# use this to squeeze the 2 subplots super close to cover the category labels
plt.subplots_adjust(hspace=0.01) 
plt.title('MaSp2:Actin in Major',y=1.55, fontsize=20)

sns.boxplot(x='Diet',y='MaSp2:actin',data=all_genes,ax=axes[0])

axes[0].set_ylim(2*1e6,1.5*1e7)
axes[0].set_ylabel('')
axes[0].tick_params(labelsize=15)

#sns.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)

a=sns.boxplot(x='Diet',y='MaSp2:actin',data=all_genes,ax=axes[1])

axes[1].set_ylim(0,1*1e6)
axes[1].set_ylabel('')
axes[1].set_xlabel('')
axes[1].tick_params(labelsize=15)
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
t= axes[1].text(-0.14,0.95,'=====',size=14,ha='left',transform=axes[1].transAxes)
t.set_bbox(dict(facecolor='white',edgecolor='white'))


plt.savefig("SA_MaSp2 to Actin in Major.pdf")

# %%
a = sns.boxplot(x='Diet',y='MaSp2:actin',data=all_genes,palette='colorblind')
a.set_xlabel('MaSp2:Actin', fontsize=15)
a.set_ylabel('Diet', fontsize=15)
a.tick_params(labelsize=15)
a.set_ylabel('')
a.set_xlabel('')
a.axes.set_title('MaSp2 to Actin in Major', fontsize=18)
plt.savefig("SA_MaSp2 to Actin in Major.pdf")

# %%
# make the 2 subplots have different heights
f, axes = plt.subplots(nrows=2, ncols=1, sharex=True, sharey=False,
                       gridspec_kw={'height_ratios':[1,2]}) 

# use this to squeeze the 2 subplots super close to cover the category labels
plt.subplots_adjust(hspace=0.01) 
plt.title('MaSp1 in Major',y=1.55)
plt.ticklabel_format(style='sci',axis='y',scilimits=(0,4))
sns.despine(bottom=True)
sns.boxplot(x='Diet',y='MaSp1',data=all_genes,ax=axes[0])

axes[0].set_ylim(0.7*1e7,2.5*1e7)
axes[0].set_ylabel('')
axes[0].set_xlabel('')

#sns.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)
plt.ticklabel_format(style='sci',axis='y',scilimits=(0,0))
sns.boxplot(x='Diet',y='MaSp1',data=all_genes,ax=axes[1])
axes[1].set_ylim(0,5.3*1e6)
axes[1].set_ylabel('')
axes[1].set_xlabel('')
t= axes[1].text(-0.07,0.95,'==',size=14,ha='left',transform=axes[1].transAxes)
t.set_bbox(dict(facecolor='white',edgecolor='white'))


plt.savefig('SA_MaSp1 in Major.png') # SA for split axis

# %%
sns.boxplot(x='Diet',y='Actin',data=all_genes)

# %%
ax = sns.boxplot(x='Diet',y='Actin',data=all_genes)
plt.title('Actin in Major')

ax.set_ylabel('')
ax.set_xlabel('')

plt.savefig('Actin in Major.png')

# %%
ax = sns.boxplot(x='Diet',y='Actin',data=all_genes_mi)
plt.title('Actin in Minor')

ax.set_ylabel('')
ax.set_xlabel('')

plt.savefig('Actin in Minor.png')

# %% [markdown]
# MaSp2 and actin don't need split axis, use old graphs

# %% [markdown]
# # Minor ampullate plots

# %%
all_genes_mi=pd.read_excel('All genes.xlsx','Minor')

# %%
all_genes_mi.head()
# Out:
#               Diet  Sample          MiSp         MaSp1         MaSp2  \
# 0     baseline n=4      11  1.569928e+06  2.775322e+06  4.112668e+06
# 1     baseline n=4      17  3.699165e+06  1.052320e+05  8.758164e+04
# 2     baseline n=4      21  2.404514e+06  2.677369e+04  1.009195e+05
# 3     baseline n=4      24  8.100560e+05  2.483446e+02  1.049340e+03
# 4  cricket-fed n=5      30  1.041075e+06  7.120356e+03  1.312229e+04
#
#           Actin   MiSp/MaSp1  MiSp/MaSp2  MiSp/Actin  MaSp1:MaSp2  \
# 0   4564.442953     0.565674    0.381730  343.947297     0.674823
# 1   6249.100048    35.152479   42.236760  591.951596     1.201530
# 2  11554.339930    89.808840   23.826072  208.104862     0.265298
# 3   1362.793480  3261.822540  771.967007  594.408487     0.236667
# 4   4471.880554   146.211146   79.336437  232.804827     0.542616
#
#    MaSp1:actin  MaSp2:actin
# 0   608.030769   901.022912
# 1    16.839541    14.015081
# 2     2.317198     8.734334
# 3     0.182232     0.769992
# ...

# %%
a = sns.boxplot(x='Diet',y='MiSp/Actin',data=all_genes_mi,palette='colorblind')
a.set_xlabel('MiSp:Actin', fontsize=15)
a.set_ylabel('Diet', fontsize=15)
a.tick_params(labelsize=15)
a.set_ylabel('MiSp/Actin')
a.set_xlabel('')
a.axes.set_title('MiSp to Actin in Minor', fontsize=18)
plt.savefig("SA_MiSp to Actin in Minor.pdf")

# %%
from PIL import Image
import io

ax=sns.boxplot(x='Diet',y='MiSp/Actin',data=all_genes_mi)
ax.set_xlabel('')
ax.set_ylabel('')
plt.title('MiSp:Actin in minor', fontsize=18)
ax.tick_params(labelsize=15)

png1 = io.BytesIO()
plt.savefig(png1, format="png")

# Load this image into PIL
png2 = Image.open(png1)

# Save as TIFF
png2.save("MiSp to Actin in minor.tiff")
png1.close()

# %%
sns.boxplot(x='Diet',y='MaSp1:MaSp2',data=all_genes_mi)
ax.set_xlabel('')
ax.set_ylabel('')
plt.title('MaSp1 to MaSp2 in minor', fontsize=18)
ax.tick_params(labelsize=15)
plt.savefig('MaSp1 to MaSp2 in minor.pdf')

# %%
from PIL import Image
import io

# make the 2 subplots have different heights
f, axes = plt.subplots(nrows=2, ncols=1, sharex=True, sharey=False,
                       gridspec_kw={'height_ratios':[1,2]}) 

# use this to squeeze the 2 subplots super close to cover the category labels
plt.subplots_adjust(hspace=0.01) 
plt.title('MaSp1:MaSp2 in minor',y=1.55, fontsize=18)
plt.ticklabel_format(style='sci',axis='y',scilimits=(0,0))
sns.boxplot(x='Diet',y='MaSp1:MaSp2',data=all_genes_mi,ax=axes[0])

axes[0].set_ylim(11,12)
axes[0].set_ylabel('')
axes[0].set_xlabel('')
axes[0].tick_params(labelsize=15)


#sns.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)
plt.ticklabel_format(style='sci',axis='y',scilimits=(0,0))
ax=sns.boxplot(x='Diet',y='MaSp1:MaSp2',data=all_genes_mi,ax=axes[1])
ax.tick_params(labelsize=15)
axes[1].set_ylim(0,2)
axes[1].set_ylabel('')
axes[1].set_xlabel('')
t= axes[1].text(-0.12,0.95,'====',size=14,ha='left',transform=axes[1].transAxes)
t.set_bbox(dict(facecolor='white',edgecolor='white'))

plt.savefig("SA_MaSp1 to MaSp2 in Minor.pdf")

# %%
# make the 2 subplots have different heights
f, axes = plt.subplots(nrows=2, ncols=1, sharex=True, sharey=False,
                       gridspec_kw={'height_ratios':[1,2]}) 

# use this to squeeze the 2 subplots super close to cover the category labels
plt.subplots_adjust(hspace=0.01) 
plt.title('MaSp1:Actin in minor',y=1.55, fontsize=18)
#plt.ticklabel_format(style='sci',axis='y',scilimits=(0,0))
#sns.despine(bottom=True)
sns.boxplot(x='Diet',y='MaSp1:actin',data=all_genes_mi,ax=axes[0])

axes[0].set_ylim(550,650)
axes[0].set_ylabel('')
axes[0].set_xlabel('')
axes[0].tick_params(labelsize=15)

#sns.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)
#plt.ticklabel_format(style='sci',axis='y',scilimits=(0,0))
sns.boxplot(x='Diet',y='MaSp1:actin',data=all_genes_mi,ax=axes[1])
axes[1].set_ylim(0,250)
axes[1].set_ylabel('')
axes[1].set_xlabel('')
axes[1].tick_params(labelsize=15)
t= axes[1].text(-0.11,0.95,'===',size=14,ha='left',transform=axes[1].transAxes)
t.set_bbox(dict(facecolor='white',edgecolor='white'))

plt.savefig("SA_MaSp1 to Actin in Minor.pdf")

# %%
from PIL import Image
import io

# make the 2 subplots have different heights
f, axes = plt.subplots(nrows=2, ncols=1, sharex=True, sharey=False,
                       gridspec_kw={'height_ratios':[1,2]}) 

# use this to squeeze the 2 subplots super close to cover the category labels
plt.subplots_adjust(hspace=0.01) 
plt.title('MaSp2:Actin in minor',y=1.55, fontsize=18)
#plt.ticklabel_format(style='sci',axis='y',scilimits=(0,0))
#sns.despine(bottom=True)
sns.boxplot(x='Diet',y='MaSp2:actin',data=all_genes_mi,ax=axes[0])

axes[0].set_ylim(700,920)
axes[0].set_ylabel('')
axes[0].set_xlabel('')
axes[0].tick_params(labelsize=15)

#sns.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)
#plt.ticklabel_format(style='sci',axis='y',scilimits=(0,0))
sns.boxplot(x='Diet',y='MaSp2:actin',data=all_genes_mi,ax=axes[1])
axes[1].set_ylim(0,240)
axes[1].set_ylabel('')
axes[1].set_xlabel('')
axes[1].tick_params(labelsize=15)
t= axes[1].text(-0.11,0.95,'===',size=14,ha='left',transform=axes[1].transAxes)
t.set_bbox(dict(facecolor='white',edgecolor='white'))

plt.savefig("SA_MaSp2 to Actin in Minor.pdf")

# %%
# make the 2 subplots have different heights
f, axes = plt.subplots(nrows=2, ncols=1, sharex=True, sharey=False,
                       gridspec_kw={'height_ratios':[1,2]}) 
plt.ticklabel_format(style='sci',axis='y',scilimits=(0,5))
# use this to squeeze the 2 subplots super close to cover the category labels
plt.subplots_adjust(hspace=0.01) 
plt.title('MiSp:MaSp1 in minor',y=1.55)

sns.despine(bottom=True)
sns.boxplot(x='Diet',y='MiSp/MaSp1',data=all_genes_mi,ax=axes[0])

axes[0].set_ylim(1.2*1e4,1.4*1e4)
axes[0].set_ylabel('')
axes[0].set_xlabel('')

#sns.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)
#plt.ticklabel_format(style='sci',axis='y',scilimits=(0,0))
sns.boxplot(x='Diet',y='MiSp/MaSp1',data=all_genes_mi,ax=axes[1])
axes[1].set_ylim(0,7000)
axes[1].set_ylabel('')
axes[1].set_xlabel('')
t= axes[1].text(-0.1,0.95,'===',size=14,ha='left',transform=axes[1].transAxes)
t.set_bbox(dict(facecolor='white',edgecolor='white'))
plt.savefig('SA_MiSp to MaSp1 in Minor.png') # SA for split axis

# %%
# make the 2 subplots have different heights
f, axes = plt.subplots(nrows=2, ncols=1, sharex=True, sharey=False,
                       gridspec_kw={'height_ratios':[1,2]}) 
#plt.ticklabel_format(style='sci',axis='y',scilimits=(0,5))
# use this to squeeze the 2 subplots super close to cover the category labels
plt.subplots_adjust(hspace=0.01) 
plt.title('MiSp:MaSp2 in minor',y=1.55)

sns.despine(bottom=True)
sns.boxplot(x='Diet',y='MiSp/MaSp2',data=all_genes_mi,ax=axes[0])

axes[0].set_ylim(76000,77000)
axes[0].set_ylabel('')
axes[0].set_xlabel('')

#sns.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)
#plt.ticklabel_format(style='sci',axis='y',scilimits=(0,0))
sns.boxplot(x='Diet',y='MiSp/MaSp2',data=all_genes_mi,ax=axes[1])
axes[1].set_ylim(0,7000)
axes[1].set_ylabel('')
axes[1].set_xlabel('')
t= axes[1].text(-0.1,0.95,'===',size=14,ha='left',transform=axes[1].transAxes)
t.set_bbox(dict(facecolor='white',edgecolor='white'))
#plt.savefig('SA_MiSp to MaSp2 in Minor.png') # SA for split axis

# %% [markdown]
# MiSp to actin, MiSp, and actin don't need split axis

# %%
ax = sns.boxplot(x='Diet',y='MiSp',data=all_genes_mi)
ax.set_ylabel('')
ax.set_xlabel('')
plt.title('MiSp Total Abundance')
plt.savefig('MiSp itself.png')

# %%
# make the 2 subplots have different heights
f, axes = plt.subplots(nrows=2, ncols=1, sharex=True, sharey=False,
                       gridspec_kw={'height_ratios':[1,2]}) 
#plt.ticklabel_format(style='sci',axis='y',scilimits=(0,0))
# use this to squeeze the 2 subplots super close to cover the category labels
plt.subplots_adjust(hspace=0.01) 
plt.title('MaSp1 in minor',y=1.55)

sns.despine(bottom=True)
sns.boxplot(x='Diet',y='MaSp1',data=all_genes_mi,ax=axes[0])

axes[0].set_ylim(2700000,2900000)
axes[0].set_ylabel('')
axes[0].set_xlabel('')

#sns.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)
#plt.ticklabel_format(style='sci',axis='y',scilimits=(0,0))
sns.boxplot(x='Diet',y='MaSp1',data=all_genes_mi,ax=axes[1])
axes[1].set_ylim(0,920000)
axes[1].set_ylabel('')
axes[1].set_xlabel('')
t= axes[1].text(-0.13,0.95,'====',size=14,ha='left',transform=axes[1].transAxes)
t.set_bbox(dict(facecolor='white',edgecolor='white'))
plt.savefig('SA_MaSp1 in Minor.png') # SA for split axis

# %%
# make the 2 subplots have different heights
f, axes = plt.subplots(nrows=2, ncols=1, sharex=True, sharey=False,
                       gridspec_kw={'height_ratios':[1,2]}) 
#plt.ticklabel_format(style='sci',axis='y',scilimits=(0,0))
# use this to squeeze the 2 subplots super close to cover the category labels
plt.subplots_adjust(hspace=0.01) 
plt.title('MaSp2 in minor',y=1.55)

sns.despine(bottom=True)
sns.boxplot(x='Diet',y='MaSp2',data=all_genes_mi,ax=axes[0])

axes[0].set_ylim(4000000,4200000)
axes[0].set_ylabel('')
axes[0].set_xlabel('')

#sns.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)
#plt.ticklabel_format(style='sci',axis='y',scilimits=(0,0))
sns.boxplot(x='Diet',y='MaSp2',data=all_genes_mi,ax=axes[1])
axes[1].set_ylim(0,2000000)
axes[1].set_ylabel('')
axes[1].set_xlabel('')
t= axes[1].text(-0.13,0.95,'====',size=14,ha='left',transform=axes[1].transAxes)
t.set_bbox(dict(facecolor='white',edgecolor='white'))
plt.savefig('SA_MaSp2 in Minor.png') # SA for split axis

# %% [markdown]
# # Tukey post-hoc pairwise test

# %%
misp = pd.read_excel('MiSp actin Tukey.xlsx','MiSp')
actin = pd.read_excel('MiSp actin Tukey.xlsx','Actin in minor')

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from statsmodels.stats.multicomp import MultiComparison

# %%
mc = MultiComparison(all_genes_mi['MiSp'],all_genes_mi['Diet'])
result = mc.tukeyhsd()

print('Tukey test for MiSp:')
print(result)
print(mc.groupsunique)
# Out:
# Tukey test for MiSp:
#               Multiple Comparison of Means - Tukey HSD,FWER=0.05
# ...
#      group1          group2        meandiff       lower        upper    reject
# ------------------------------------------------------------------------------
#   baseline n=4  cricket-fed n=5 -1021533.2023 -2369773.0822 326706.6775 False
#   baseline n=4    fly-fed n=5   -1403420.2432 -2751660.1231 -55180.3634  True
# cricket-fed n=5   fly-fed n=5    -381887.0409 -1653019.7899  889245.708 False
# ------------------------------------------------------------------------------
# ['baseline n=4' 'cricket-fed n=5' 'fly-fed n=5']

# %%
mc = MultiComparison(all_genes_mi['MaSp2'],all_genes_mi['Diet'])
result = mc.tukeyhsd()

print('Tukey test for MaSp2:')
print(result)
print(mc.groupsunique)
# Out:
# Tukey test for MaSp2:
#                Multiple Comparison of Means - Tukey HSD,FWER=0.05
# ...
#      group1          group2        meandiff       lower        upper     reject
# -------------------------------------------------------------------------------
#   baseline n=4  cricket-fed n=5 -1010033.1452 -3080182.4875 1060116.1971 False
#   baseline n=4    fly-fed n=5    -605421.6659 -2675571.0082 1464727.6764 False
# cricket-fed n=5   fly-fed n=5    404611.4793   -1547144.038 2356366.9966 False
# -------------------------------------------------------------------------------
# ['baseline n=4' 'cricket-fed n=5' 'fly-fed n=5']

# %%
all_genes_new = pd.read_excel('All genes new.xlsx','Major')
all_genes_mi_new = pd.read_excel('All genes new.xlsx','Minor')

# %%
#import matplotlib.ticker as mtick
import numpy as np
ax = sns.boxplot(x='Diet',y='Total abundance (million copies / 2ng RNA)',hue='Gene',data=all_genes_new,palette='colorblind')
# maybe hide 'Diet'
ax.set_xlabel('')

#tick_labels = np.around(1/new_tick_loc*1e4,decimals=-2)
#ax.set_xticklabels(tick_labels.astype(int))

ax.set_ylabel('Total abundance (million copies / 2ng RNA)',fontsize=15)

for ax in plt.gcf().axes:
    l = ax.get_xlabel()
    ax.set_xlabel(l, fontsize=15)
ax.tick_params(labelsize=15)
#ax.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.'))
plt.title('Total Abundance in Major', fontsize=18)

plt.savefig("All total abundance in major.pdf")

# %% [markdown]
# For Actin in major, n=5 for baseline, n=4 for fly-fed but I have to label it the same as the other genes in the plot. Maybe mention this in the figure legend.

# %%
ax=sns.boxplot(x='Diet',y='Total abundance (million copies / 2ng RNA)',hue='Gene',data=all_genes_mi_new,palette='colorblind')
ax.set_xlabel('')
ax.set_ylabel('Total abundance (million copies / 2ng RNA)', fontsize=15)
for ax in plt.gcf().axes:
    l = ax.get_xlabel()
    ax.set_xlabel(l, fontsize=15)
ax.tick_params(labelsize=15)

plt.title('Total Abundance in Minor', fontsize=18)
plt.savefig("All total abundance in minor.pdf")

# %%
actin = pd.read_excel('Just actin.xlsx')
ax=sns.boxplot(x='Diet_n',y='Total_abundance',hue='Gland',data=actin,palette='colorblind')
ax.set_xlabel('')
ax.set_ylabel('Total abundance (million copies / 2ng RNA)', fontsize=15)

ax.tick_params(labelsize=15)
for ax in plt.gcf().axes:
    l = ax.get_xlabel()
    ax.set_xlabel(l, fontsize=15)
ax.set_ylabel('Total abundance (copies / 2ng RNA)')
plt.title('Actin Total Abundance', fontsize=18)

plt.savefig("Just actin.pdf")
